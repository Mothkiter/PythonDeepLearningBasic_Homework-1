# %%
import requests
from bs4 import BeautifulSoup

# %%
elm = input('输入你想要查询的元素')
elm = elm.capitalize()
url = 'https://ptable.com/JSON/compounds/formula='+elm

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36 Edg/111.0.1661.54'}
response = requests.get(url,headers = headers)
response_txt = response.text

# %%
import ast
import json

# %%
str_dict = bs.get_text()
print(str_dict)
# Out:
# {"matches":[{"molecularformula":"Na","allnames":["sodium","natrium","sodium metal"],"articles":["Sodium","Sodium",""],"ordered":"11"},{"molecularformula":"NaBH4","allnames":["sodium borohydride","sodium boron(-1) anion"],"articles":["Sodium borohydride",""],"ordered":"5,11"},{"molecularformula":"NaBr","allnames":["sodium bromide","bromide salt of sodium","hydrobromic acid sodium salt","sedoneural"],"articles":["Sodium bromide","","",""],"ordered":"11,35"},{"molecularformula":"NaCl","allnames":["sodium chloride","common salt","rock salt","salt","table salt"],"articles":["Sodium chloride","Sodium chloride","Halite","Salt","Salt"],"ordered":"11,17"},{"molecularformula":"Na^35Cl","allnames":["sodium chloride-35","sodium chloride-35Cl"],"articles":["",""],"ordered":"11,17"},{"molecularformula":"NaF","allnames":["sodium fluoride","antibulit","chemifluor","floridine","sodium monofluoride"],"articles":["Sodium fluoride","","","",""],"ordered":"9,11"},{"molecularformula":"NaH","allnames":["so
# ...

# %%
dict_json = json.loads(str_dict)
# Out:
# {'matches': [{'molecularformula': 'Na', 'allnames': ['sodium', 'natrium', 'sodium metal'], 'articles': ['Sodium', 'Sodium', ''], 'ordered': '11'}, {'molecularformula': 'NaBH4', 'allnames': ['sodium borohydride', 'sodium boron(-1) anion'], 'articles': ['Sodium borohydride', ''], 'ordered': '5,11'}, {'molecularformula': 'NaBr', 'allnames': ['sodium bromide', 'bromide salt of sodium', 'hydrobromic acid sodium salt', 'sedoneural'], 'articles': ['Sodium bromide', '', '', ''], 'ordered': '11,35'}, {'molecularformula': 'NaCl', 'allnames': ['sodium chloride', 'common salt', 'rock salt', 'salt', 'table salt'], 'articles': ['Sodium chloride', 'Sodium chloride', 'Halite', 'Salt', 'Salt'], 'ordered': '11,17'}, {'molecularformula': 'Na^35Cl', 'allnames': ['sodium chloride-35', 'sodium chloride-35Cl'], 'articles': ['', ''], 'ordered': '11,17'}, {'molecularformula': 'NaF', 'allnames': ['sodium fluoride', 'antibulit', 'chemifluor', 'floridine', 'sodium monofluoride'], 'articles': ['Sodium fluoride',
# ...

# %%
l = [dict_json['matches'][i]['molecularformula'] for i in range(5)]

# %%
print(l)
# Out:
# ['Na', 'NaBH4', 'NaBr', 'NaCl', 'Na^35Cl']

# %%
import requests

headers = {
    'authority': 'sessions.bugsnag.com',
    'accept': '*/*',
    'accept-language': 'zh-CN,zh;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'bugsnag-api-key': '89a7744f0a74c197fd23f560afed1170',
    'bugsnag-payload-version': '1',
    'bugsnag-sent-at': '2023-04-05T07:17:49.348Z',
    'content-type': 'application/json',
    'origin': 'https://ptable.com',
    'referer': 'https://ptable.com/',
    'sec-ch-ua': '"Microsoft Edge";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'cross-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36 Edg/111.0.1661.62',
}

# json_data = {
#     'notifier': {
#         'name': 'Bugsnag JavaScript',
#         'version': '7.17.0',
#         'url': 'https://github.com/bugsnag/bugsnag-js',
#     },
#     'device': {
#         'locale': 'zh-CN',
#         'userAgent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36 Edg/111.0.1661.62',
#         'orientation': 'landscape-primary',
#         'id': 'clg3cve4c00003n68fqkgswyd',
#     },
#     'app': {
#         'releaseStage': 'production',
#         'version': 'new-dd8f737',
#         'type': 'browser',
#     },
#     'sessions': [
#         {
#             'id': 'clg3cx9k300023n68odsgtu44',
#             'startedAt': '2023-04-05T07:17:49.347Z',
#             'user': {},
#         },
#     ],
# }

response = requests.post('https://ptable.com/?lang=en#Properties/Series', headers=headers)

# %%
with open('D:\Wangzhen\大学\大三下\python 深度学习\Homework 1\content.html','w',encoding='utf-8') as w:
    w.write(str(bs.prettify()))

# %%
# 打印响应内容
print(response)
# Out:
# <Response [200]>

# %%
print(response.content)
# Out:
# b'<!doctype html>\n<html lang="en-US" data-iso="en" data-wiki="en" dir="ltr" class="Property" data-wide="0" translate="no">\n<!-- toggled classes: Sidebar, Collapse, [Tab], Dark, SmoothResize, NoTransitions, FullScreen -->\n <head>\n  <title>Periodic Table - Ptable</title>\n  <script>\n  const dark_os_theme = window.matchMedia("(prefers-color-scheme: dark)").matches;\n  const theme_set = localStorage.getItem("Theme");\n  const dark_set = localStorage.getItem("Theme") === "Dark";\n  const layout_set = localStorage.getItem("Layout");\n  const layout_sidebar_set = localStorage.getItem("Layout") === "Sidebar";\n  const wide_enough_but_not_tall = window.matchMedia("(min-width: 1200px) and (min-aspect-ratio: 6/5), (min-width: 1024px) and (min-aspect-ratio: 6/5) and (-webkit-min-device-pixel-ratio: 2)").matches;\n\n  if (dark_set || (dark_os_theme && !theme_set)) {\n  \tdocument.documentElement.classList.add("Dark");\n  \tdocument.documentElement.style.colorScheme = "dark";\n  }\n  if (layo
# ...

# %%
bs = BeautifulSoup(response.content)
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html class="Property" data-iso="en" data-wide="0" data-wiki="en" dir="ltr" lang="en-US" translate="no">
#  <!-- toggled classes: Sidebar, Collapse, [Tab], Dark, SmoothResize, NoTransitions, FullScreen -->
#  <head>
#   <title>
#    Periodic Table - Ptable
#   </title>
#   <script>
#    const dark_os_theme = window.matchMedia("(prefers-color-scheme: dark)").matches;
#   const theme_set = localStorage.getItem("Theme");
#   const dark_set = localStorage.getItem("Theme") === "Dark";
#   const layout_set = localStorage.getItem("Layout");
#   const layout_sidebar_set = localStorage.getItem("Layout") === "Sidebar";
#   const wide_enough_but_not_tall = window.matchMedia("(min-width: 1200px) and (min-aspect-ratio: 6/5), (min-width: 1024px) and (min-aspect-ratio: 6/5) and (-webkit-min-device-pixel-ratio: 2)").matches;
#
#   if (dark_set || (dark_os_theme && !theme_set)) {
#   	document.documentElement.classList.add("Dark");
# ...

# %%
bs.find_all('li')
# Out:
# [<li>
#  <label><span></span></label>
#  <output></output>
#  </li>,
#  <li>
#  <label for="t_series"><span>Series</span></label>
#  <output></output>
#  </li>,
#  <li>
#  <label for="t_name"><span>Write-up</span></label>
#  <output id="AsideWriteup"><a href="https://en.wikipedia.org/">Wikipedia</a></output>
#  <select><option value="Wikipedia">Wikipedia</option></select> </li>,
#  <li>
#  <label for="t_state"><span>State at</span> <input data-unit="C" id="Temperature" max="5727" min="-273" type="number" value="0"/><select class="Temperature"><option value="C">°C</option><option value="F">°F</option><option value="K">K</option></select></label>
#  <output></output>
#  </li>,
#  <li>
#  <label for="t_weight"><span>Weight</span></label>
#  <output></output>
#  <select class="AMU"><option value="u">u</option></select> </li>,
#  <li>
#  <label for="t_electrons"><span>Energy levels</span></label>
#  <output></output>
#  </li>,
#  <li>
# ...
